# %% [markdown]
# # Instant Visualization of Twitter Data

# %% [markdown]
# ## Team Dahlia --Meihao Chen, Yitong Wang

# %% [markdown]
# ## General Descrition of the Dataset -- a lot of Counts

# %%
import json
import sys
import string
import nltk
import goose
from pprint import pprint
import collections
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline
import shlex, subprocess
from operator import *
from support import *

# %%
analyze_count(parse_count(get_count()), "Number of tweets by time series")
# Out:
# Total number of tweet is : 1613955

# %%
# Open up the mapreduce results
hillary_user = open('./results/result_user.txt', 'rb')
hillary_location = open('./results/result_loca.txt', 'rb')
hillary_hashtag = open('./results/result_hash.txt', 'rb')
hillary_mention = open('./results/result_mention.txt', 'rb')
hillary_tweet = open('./results/result_tweet.txt', 'rb')
oscar_user = open('./results/nameCount','rb')
oscar_location = open('./results/locationCount','rb')
oscar_hashtag = open('./results/hashtagCount','rb')
oscar_mention = open('./results/mentionCount','rb')
oscar_tweet = open('./results/retweetCount','rb')
oscar_source = open('./results/sourceCount','rb')

# %%
# Obtain the top N results from each field
hillary_users_top = sortLine(hillary_user, 15)
hillary_loca_top = sortLine(hillary_location, 10)
hillary_hash_top = sortLine(hillary_hashtag, 10)
hillary_mention_top = sortLine(hillary_mention, 15)
hillary_tweet_top = sortLine(hillary_tweet, 10)
oscar_user_top = sortLine(oscar_user, 15)
oscar_location_top = sortLine(oscar_location, 15)
oscar_hashtag_top = sortLine(oscar_hashtag, 15)
oscar_mention_top = sortLine(oscar_mention, 15)
oscar_tweet_top = sortLine(oscar_tweet, 15)
oscar_source_top = sortLine(oscar_source, 15)

# %% [markdown]
# ###Graphs from Hillary Data

# %%
# Most active users in the 48 hour period
graphing(hillary_users_top, 'Most active users #Hillary')

# %%
# top 10 locations where the users are the most active
graphing(hillary_loca_top, 'Most active locations #Hillary')

# %%
# Most mentioned hashtags in the 48 hour period
graphing(hillary_hash_top, 'Most mentioned hashtags #Hillary')

# %%
# Top 15 people that are mentioned the most in the 48 hour period
graphing(hillary_mention_top, 'Most mentioned people #Hillary')

# %%
# Most re-tweeted tweets in the 48 hour periods
hillary_tweet_top
# Out:
# [('yaaas @hillaryclinton', 10235),
#  ("BREAKING NEWS: It's official. @HillaryClinton has just announced she is running for president. http://t.co/2mcPLTpliB http://t.co/il3Y8siw6U",
#   10192),
#  ('BREAKING: Hillary Rodham Clinton enters White House race; Democrat seeks to be first female president.',
#   7745),
#  ('Very proud of you Mom! @HillaryClinton: http://t.co/PvMlg82cU2', 5069),
#  ('favorite - hillary clinton http://t.co/o4RCQzXbxN', 4931),
#  ("Hillary Clinton announced she's runnin' for President in 2016. Now millions of Republicans will be sexist instead of racist. Merica.",
#   4777),
#  ('Bill and Barack go on tour and stunt while their wives run the world.',
#   3834),
#  ('Clinton is officially running for President - have your #EverydaySexism bingo card to hand #HillaryForAmerica http://t.co/CPpN9Y4k8i',
#   3657),
#  ('Fav ~ Hillary Clinton http://t.co/neAgnsiflW', 3293),
# ...

# %% [markdown]
# ### Graphs from Oscar Data

# %%
graphing(oscar_user_top, 'Most active user #Oscar')

# %%
graphing(oscar_location_top, 'Most active locations #Oscar')

# %%
graphing(oscar_hashtag_top, 'Most mentioned hashtag #Oscar')

# %%
graphing(oscar_mention_top, 'Most mentioned people #Oscar')

# %%
graphing(oscar_source_top,'Most popular source #Oscar')

# %%
oscar_tweet_top
# Out:
# [('"if only bradley\'s arm was longer. best photo ever. #oscars http://t.co/c9u5notgap"',
#   116971),
#  ('"#oscars #blessed #blurry http://t.co/gso8vyj34z"', 9666),
#  ('"#besties #oscars2014 http://t.co/gpg9px5i2h"', 4043),
#  ('"leonardo dicaprio, johnny depp, robert downey jr &amp; will smith have never won an oscar. this validates the fact that award shows are bullshit"',
#   3759),
#  ('"thanks for watching and tweeting! now i need to meet with my friend, margarita. see you tomorrow for my live show! #oscars"',
#   3179),
#  ('"hasta censuran #oscars2014 que culillo tan grande!quieren censurar todo pero con eso no resuelven los problemas y el descontento sigue"',
#   2571),
#  ('"my photobombing gets better and better! @theellenshow #oscars http://t.co/lyokefgtht"',
#   2283),
#  ('"here we go #oscars http://t.co/iia8ahxcse"', 2280),
#  ('"just arrived on the oscars red carpet http://t.co/j1vuxcywah"', 2258),
# ...

# %% [markdown]
# # Name Recognition with NLTK

# %% [markdown]
# Lots of celebrities are mentioned in Oscar related tweets without @.

# %% [markdown]
# We use NLTK to generate position tag for each word in a sentence, and if there are nodes with label 'PERSON' it is grabbed. Consecutive 'PERSON's are concatinated in to one name.

# %%
text = "Irina Shayk will attend the Oscars tonight, hosted by the one &amp; only Ellen DeGeneres."

# %%
from nameRecognition import *

# %%
get_human_names(text)
# Out:
# ['Ellen DeGeneres']

# %%
nameInTweet = open('./results/nameInTweetCount')
nameInTweet_top = sortLine(nameInTweet, 50)

# %%
graphing(nameInTweet_top, 'Names in Tweets #Oscar')

# %% [markdown]
# # Following Tasks

# %% [markdown]
# ### Query search

# %% [markdown]
# ### Improve name recognition

# %% [markdown]
# ### Sentiment analysis
